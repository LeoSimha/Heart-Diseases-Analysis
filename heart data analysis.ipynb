# %%
import numpy as np
import pandas as pd
import os

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st
# %matplotlib inline

sns.set(style='darkgrid')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'E:\AI & DS\Projects and Task\heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.shape
# Out:
# (303, 14)

# %%
df.head
# Out:
# <bound method NDFrame.head of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]>

# %%
df.info
# Out:
# <bound method DataFrame.info of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]>

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df['target'].nunique()
# Out:
# 2

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(18, 8))
ax = sns.countplot(x="target", data=df)
plt.show()

# %%
df.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="sex", hue="target", data=df)
plt.show()

# %%
ax = sns.catplot(x = 'target', col = 'sex', data = df, kind = 'count', height = 5, aspect = .8)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="cp", hue="target", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=df, palette = 'Set3')
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=df, facecolor=(0, 0, 0, 0),linewidth=5,edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="fbs", data=df)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="exang", data=df)
plt.show()

# %%
correlation = df.corr()
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
df['cp'].nunique()
# Out:
# 4

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="cp", data=df)
plt.show()

# %%
df.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="cp", hue="target", data=df)
plt.show()

# %%
ax = sns.catplot(x = 'target', col = 'cp', data = df, kind = 'count', height = 5, aspect = .8)

# %%
df['thalach'].nunique()
# Out:
# 91

# %%
f, ax = plt.subplots(figsize=(12, 6))
x = df['thalach']
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(12, 6))
x = df['thalach']
x= pd.Series(x, name='thalach values')
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
x = df['thalach']
ax = sns.displot(x, bins=10, vertical=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 f, ax = plt.subplots(figsize=(10, 6))
#       2 x = df['thalach']
# ----> 3 ax = sns.displot(x, bins=10, vertical=True)
#       4 plt.show()
#
# File c:\Users\Pruth\anaconda3\Lib\site-packages\seaborn\distributions.py:2193, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2190 if p.univariate:
#    2192     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2193     p.plot_univariate_histogram(**hist_kws)
#    2195 else:
#    2197     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# File c:\Users\Pruth\anaconda3\Lib\site-packages\seaborn\distributions.py:571, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     566 if element == "bars":
#     567
#     568     # Use matplotlib bar plotting
#     570     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 571     artists = plot_func(
#     572         hist["edges"],
#     573         hist["heights"] - bottom,
#     574         hist["widths"],
#     575         bottom,
#     576         align="edge",
#     577         **artist_kws,
#     578     )
#     580     for bar in artists:
#     581         if self.data_variable == "x":
#
# File c:\Users\Pruth\anaconda3\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Pruth\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2532, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2523 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2524     r = mpatches.Rectangle(
#    2525         xy=(l, b), width=w, height=h,
#    2526         facecolor=c,
#    (...)
#    2530         hatch=htch,
#    2531         )
# -> 2532     r._internal_update(kwargs)
#    2533     r.get_path()._interpolation_steps = 100
#    2534     if orientation == 'vertical':
#
# File c:\Users\Pruth\anaconda3\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File c:\Users\Pruth\anaconda3\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'vertical'

# %%
f, ax = plt.subplots(figsize=(10, 6))
x = df['thalach']
x = pd.Series(x, name='thalach values')
ax = sns.kdeplot(x, shade=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
x = df['thalach']
x = pd.Series(x, name='thalach values')
ax = sns.kdeplot(x, shade=True, color="g")
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
x = df['thalach']
ax = sns.distplot(x, bins=10, kde=False, rug=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.stripplot(x="target", y="thalach", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.stripplot(x="target", y="thalach", data=df, jitter=0.01)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.boxenplot(x="target", y="thalach", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.boxplot(x="target", y="thalach", data=df)
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.violinplot(x="target", y="thalach", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.violinplot(x="target", y="thalach", data=df, hue="sex", split=True)
plt.show()

# %%
plt.figure(figsize=(16, 12))
plt.title('Correlation Heatmap')
a = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='black')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30, ha='right')
plt.show()

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target']
sns.pairplot(df[num_var], size=2.5, kind='scatter',diag_kind='hist',hue='target')
plt.show()

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
df['age'].nunique()
# Out:
# 41

# %%
f, ax = plt.subplots(figsize=(10, 6))
x = df['age']
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 6))
sns.stripplot(x="target", y="age", data=df, hue="sex")
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
sns.boxplot(x="target", y="age", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.scatterplot(x="age", y="trestbps", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.regplot(x="age", y="trestbps", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.regplot(x="age", y="trestbps", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.scatterplot(x="age", y="chol", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.regplot(x="age", y="chol", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.scatterplot(x="chol", y="thalach", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.regplot(x="chol", y="thalach", data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
assert pd.notnull(df).all().all()

# %%
assert (df>=0).all().all()

# %%
df['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(6, 4))
sns.boxplot(x = df['age'])
plt.show()

# %%
df['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f, ax = plt.subplots(figsize=(6, 4))
sns.boxplot(x = df['trestbps'])
plt.show()

# %%
df['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f, ax = plt.subplots(figsize=(6, 4))
sns.boxplot(x = df['chol'])
plt.show()

# %%
df['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f, ax = plt.subplots(figsize=(6, 4))
sns.boxplot(x = df['thalach'])
plt.show()

# %%
df['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f, ax = plt.subplots(figsize=(6, 4))
sns.boxplot(x = df['oldpeak'])
plt.show()
